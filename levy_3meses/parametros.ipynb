# %% [markdown]
# Parámetros
# | | Sector | Alpha | Beta | Loc (Mu) | Scale (Sigma) | KS Statistic | P-Value | Horizonte temporal |
# |:---:|:---|:---:|:---:|:---:|:---:|:---:|:---:|:---|
# | **0** | COME | 1.921988 | 0.999990 | 0.000520 | 0.010091 | 0.068913 | 0.914859 | 3 meses |
# | **1** | MOA | 1.623973 | 0.580927 | 0.001307 | 0.010535 | 0.047740 | 0.997955 | 3 meses |
# | **2** | MOI | 1.999994 | -0.172058 | 0.000450 | 0.012284 | 0.084171 | 0.748594 | 3 meses |
# | **3** | AGRO | 1.999998 | 0.297929 | 0.000234 | 0.013766 | 0.047142 | 0.998300 | 3 meses |
# | **4** | ENE | 2.000000 | -1.000000 | 0.002323 | 0.018403 | 0.063658 | 0.952397 | 3 meses |
# | **5** | FIN | 1.907617 | -0.999973 | -0.002929 | 0.017263 | 0.059350 | 0.973944 | 3 meses |
# | **6** | TOTAL | 2.000000 | -1.000000 | 0.001161 | 0.012511 | 0.101851 | 0.518578 | 3 meses |

# %%
#simu2mdo_ae
# Parámetros con colas más pesadas (Alpha reducido  en un 20% para aumentar Curtosis)
params_COME = {"alpha": 1.921988, "beta": 0.999990, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.99}
params_MOA  = {"alpha": 1.623973, "beta": 0.580927, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.99}
params_MOI  = {"alpha": 1.999994, "beta": -0.172058, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.99}
params_AGRO = {"alpha": 1.999998, "beta": 0.297929, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.99}
params_ENE  = {"alpha": 2.000000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.99}
params_FIN  = {"alpha": 1.907617, "beta": -0.999973, "mu": -0.002929, "sigma": 0.017263, "entropy": 0.99}

# %%
# simu3mdo+variab _be

#--- DEFINICIÓN DE PARÁMETROS INDEPENDIENTES ---
# Mo Se duplicó el parámetro 'sigma' (variabilidad/escala) en todos los sectores. nose pudo no converge a solución 
# Se incrementó el parámetro 'sigma' (escala) en un 30% en todos los sectores.
# Este cambio simula un aumento moderado de la volatilidad sin llegar a la duplicación previa.

params_COME = {"alpha": 1.921988, "beta": 0.999990, "mu": 0.000520, "sigma": 0.013118, "entropy": 0.30} # 0.010091 * 1.3
params_MOA  = {"alpha": 1.623973, "beta": 0.580927, "mu": 0.001307, "sigma": 0.013696, "entropy": 0.40} # 0.010535 * 1.3
params_MOI  = {"alpha": 1.999994, "beta": -0.172058, "mu": 0.000450, "sigma": 0.015969, "entropy": 0.40} # 0.012284 * 1.3
params_AGRO = {"alpha": 1.999998, "beta": 0.297929, "mu": 0.000234, "sigma": 0.017896, "entropy": 0.30} # 0.013766 * 1.3
params_ENE  = {"alpha": 2.000000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.023924, "entropy": 0.30} # 0.018403 * 1.3
params_FIN  = {"alpha": 1.907617, "beta": -0.999973, "mu": -0.002929, "sigma": 0.022442, "entropy": 0.40} # 0.017263 * 1.3

# %%
#  simu4mdo+variab_ae
# Mo Se duplicó el parámetro 'sigma' (variabilidad/escala) en todos los sectores. nose pudo no converge a solución 
# Se incrementó el parámetro 'sigma' (escala) en un 30% en todos los sectores.
# Este cambio simula un aumento moderado de la volatilidad sin llegar a la duplicación previa.

params_COME = {"alpha": 1.921988, "beta": 0.999990, "mu": 0.000520, "sigma": 0.013118, "entropy": 0.990} # 0.010091 * 1.3
params_MOA  = {"alpha": 1.623973, "beta": 0.580927, "mu": 0.001307, "sigma": 0.013696, "entropy": 0.990} # 0.010535 * 1.3
params_MOI  = {"alpha": 1.999994, "beta": -0.172058, "mu": 0.000450, "sigma": 0.015969, "entropy": 0.990} # 0.012284 * 1.3
params_AGRO = {"alpha": 1.999998, "beta": 0.297929, "mu": 0.000234, "sigma": 0.017896, "entropy": 0.990} # 0.013766 * 1.3
params_ENE  = {"alpha": 2.000000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.023924, "entropy": 0.990} # 0.018403 * 1.3
params_FIN  = {"alpha": 1.907617, "beta": -0.999973, "mu": -0.002929, "sigma": 0.022442, "entropy": 0.990} # 0.017263 * 1.3

# %%
#simu5mdocp_be
# Parámetros con colas más pesadas (Alpha reducido en un 20% para aumentar Curtosis)
# Se redujo alpha para alejarlo de 2.0 (distribución normal) y generar colas más pesadas.
# A menor alpha, mayor es la probabilidad de eventos extremos (ineficiencia).

params_COME = {"alpha": 1.750000, "beta": 0.999990, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.30} # alpha bajó de 1.92 a 1.75

# Se redujo alpha de 1.62 a 1.5 para acentuar la pesadez de las colas.
params_MOA  = {"alpha": 1.50000, "beta": 0.580927, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.40} 

# Se redujo alpha de 1.99 a 1.70 para romper la simetría casi normal.
params_MOI  = {"alpha": 1.700000, "beta": -0.172058, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.40} 

# AGRO tenía un alpha de 1.99 (casi normal), se bajó a 1.75 para simular colas pesadas.
params_AGRO = {"alpha": 1.750000, "beta": 0.297929, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.30} 

# ENE era una normal perfecta (alpha=2.0), se bajó a 1.85 para introducir leptocurtosis.
params_ENE  = {"alpha": 1.850000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.30} 

# FIN se ajustó de 1.90 a 1.68 para incrementar la probabilidad de outliers.
params_FIN  = {"alpha": 1.680000, "beta": -0.999973, "mu": -0.002929, "sigma": 0.017263, "entropy": 0.40}

# %%
#simu6mdocp_ae
# Parámetros con colas más pesadas (Alpha reducido en un 20% para aumentar Curtosis)
# Se redujo alpha para alejarlo de 2.0 (distribución normal) y generar colas más pesadas.
# A menor alpha, mayor es la probabilidad de eventos extremos (ineficiencia).


params_COME = {"alpha": 1.750000, "beta": 0.999990, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.99} # alpha bajó de 1.92 a 1.75

# Se redujo alpha de 1.62 a 1.55 para acentuar la pesadez de las colas.
params_MOA  = {"alpha": 1.550000, "beta": 0.580927, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.99} 

# Se redujo alpha de 1.99 a 1.70 para romper la simetría casi normal.
params_MOI  = {"alpha": 1.700000, "beta": -0.172058, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.99} 

# AGRO tenía un alpha de 1.99 (casi normal), se bajó a 1.75 para simular colas pesadas.
params_AGRO = {"alpha": 1.750000, "beta": 0.297929, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.99} 

# ENE era una normal perfecta (alpha=2.0), se bajó a 1.85 para introducir leptocurtosis.
params_ENE  = {"alpha": 1.850000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.99} 

# FIN se ajustó de 1.90 a 1.70 para incrementar la probabilidad de outliers.
params_FIN  = {"alpha": 1.700000, "beta": -0.999973, "mu": -0.002929, "sigma": 0.017263, "entropy": 0.990}


#opción corrida actualmente 

params_COME = {"alpha": 1.740000, "beta": 0.999990, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.99} # alpha bajó de 1.92 a 1.74

# Se redujo alpha de 1.62 a 1.55 para acentuar la pesadez de las colas.
params_MOA  = {"alpha": 1.550000, "beta": 0.580927, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.99} 

# Se redujo alpha de 1.99 a 1.75 para romper la simetría casi normal.
params_MOI  = {"alpha": 1.750000, "beta": -0.172058, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.99} 

# AGRO tenía un alpha de 1.99 (casi normal), se bajó a 1.75 para simular colas pesadas.
params_AGRO = {"alpha": 1.750000, "beta": 0.297929, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.99} 

# ENE era una normal perfecta (alpha=2.0), se bajó a 1.89.
params_ENE  = {"alpha": 1.890000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.99} 

# FIN se ajustó de 1.90 a 1.70 para incrementar la probabilidad de outliers.
params_FIN  = {"alpha": 1.710000, "beta": -0.999973, "mu": -0.002929, "sigma": 0.017263, "entropy": 0.990}

# %%
# simu7mdo_asim_be

# Parámetros con asimetría extrema (Skewness severa) valores de β hacia los extremos -1 y 1
#(-1 (Asimetría total hacia la izquierda (valores negativos extremos/caídas bruscas) representa caída del mercado y 1 (Asimetría total hacia la derechavalores positivos extremos).
# Los valores positivos indican sesgo hacia ganancias extremas y los negativos hacia pérdidas extremas.

params_COME = {"alpha": 1.921988, "beta": 0.990000, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.30} # Era 0.99 (positivo), se mantuvo positivo en 0.99
params_MOA  = {"alpha": 1.623973, "beta": 0.850000, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.40} # Era 0.58 (positivo), se subió a 0.85
params_MOI  = {"alpha": 1.999994, "beta": -0.860000, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.40} # Era -0.17 (negativo), se extremó a -0.96
params_AGRO = {"alpha": 1.999998, "beta": 0.850000, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.30} # Era 0.29 (positivo), se subió a 0.85
params_ENE  = {"alpha": 2.000000, "beta": -1.00, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.30} # Era -1.0 (negativo), se mantuvo
params_FIN  = {"alpha": 1.907617, "beta": -0.999973, "mu": -0.002929, "sigma": 0.017263, "entropy": 0.40} # se mantiene

# %%
# simu8mdo_asim_ae

# Parámetros con asimetría extrema (Skewness severa) valores de β hacia los extremos -1 y 1
#(-1 (Asimetría total hacia la izquierda (valores negativos extremos/caídas bruscas) representa caída del mercado y 1 (Asimetría total hacia la derechavalores positivos extremos).
# Los valores positivos indican sesgo hacia ganancias extremas y los negativos hacia pérdidas extremas.

params_COME = {"alpha": 1.921988, "beta": 0.990000, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.99} # Era 0.99 (positivo), se mantuvo positivo en 0.99
params_MOA  = {"alpha": 1.623973, "beta": 0.850000, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.99} # Era 0.58 (positivo), se subió a 0.85
params_MOI  = {"alpha": 1.999994, "beta": -0.860000, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.99} # Era -0.17 (negativo), se extremó a -0.96
params_AGRO = {"alpha": 1.999998, "beta": 0.850000, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.99} # Era 0.29 (positivo), se subió a 0.85
params_ENE  = {"alpha": 2.000000, "beta": -1.00, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.99} # Era -1.0 (negativo), se mantuvo
params_FIN  = {"alpha": 1.907617, "beta": -0.999973, "mu": -0.002929, "sigma": 0.017263, "entropy": 0.99} # se mantiene

# %%
# normsimu9mdo_be y con alta entropia mismos parametros entropía 0.99

params_COME = {"alpha": 2.0, "beta": 0.0, "mu": 0.000683, "sigma": 0.014721, "entropy": 0.30}
params_MOA  = {"alpha": 2.0, "beta": 0.0, "mu": 0.000626, "sigma": 0.019903, "entropy": 0.40}
params_MOI  = {"alpha": 2.0, "beta": 0.0, "mu": 0.000050, "sigma": 0.017376, "entropy": 0.40}
params_AGRO = {"alpha": 2.0, "beta": 0.0, "mu": 0.000232, "sigma": 0.019465, "entropy": 0.30}
params_ENE  = {"alpha": 2.0, "beta": 0.0, "mu": 0.001795, "sigma": 0.024386, "entropy": 0.30}
params_FIN  = {"alpha": 2.0, "beta": 0.0, "mu": -0.002928, "sigma": 0.027522, "entropy": 0.40}

# %%
# Mu y Sigma actualizados según el ajuste Normal de 3 meses
# Parámetros Levy-Stable (Alpha=2, Beta=0) con Sigma aumentado un 30%
# Este ajuste simula una volatilidad moderadamente superior a la histórica.

params_COME = {"alpha": 2.0, "beta": 0.0, "mu": 0.000683, "sigma": 0.019137, "entropy": 0.30} # Sigma: 0.014721 * 1.3
params_MOA  = {"alpha": 2.0, "beta": 0.0, "mu": 0.000626, "sigma": 0.025874, "entropy": 0.40} # Sigma: 0.019903 * 1.3
params_MOI  = {"alpha": 2.0, "beta": 0.0, "mu": 0.000050, "sigma": 0.022589, "entropy": 0.40} # Sigma: 0.017376 * 1.3
params_AGRO = {"alpha": 2.0, "beta": 0.0, "mu": 0.000232, "sigma": 0.025305, "entropy": 0.30} # Sigma: 0.019465 * 1.3
params_ENE  = {"alpha": 2.0, "beta": 0.0, "mu": 0.001795, "sigma": 0.031702, "entropy": 0.30} # Sigma: 0.024386 * 1.3
params_FIN  = {"alpha": 2.0, "beta": 0.0, "mu": -0.002928, "sigma": 0.035779, "entropy": 0.40} # Sigma: 0.027522 * 1.3

# %%
params_COME = {"alpha": 2.0, "beta": 0.0, "mu": 0.000683, "sigma": 0.019137, "entropy": 0.990} # Sigma: 0.014721 * 1.3
params_MOA  = {"alpha": 2.0, "beta": 0.0, "mu": 0.000626, "sigma": 0.025874, "entropy": 0.99} # Sigma: 0.019903 * 1.3
params_MOI  = {"alpha": 2.0, "beta": 0.0, "mu": 0.000050, "sigma": 0.022589, "entropy": 0.99} # Sigma: 0.017376 * 1.3
params_AGRO = {"alpha": 2.0, "beta": 0.0, "mu": 0.000232, "sigma": 0.025305, "entropy": 0.99} # Sigma: 0.019465 * 1.3
params_ENE  = {"alpha": 2.0, "beta": 0.0, "mu": 0.001795, "sigma": 0.031702, "entropy": 0.99} # Sigma: 0.024386 * 1.3
params_FIN  = {"alpha": 2.0, "beta": 0.0, "mu": -0.002928, "sigma": 0.035779, "entropy": 0.99} # Sigma: 0.027522 * 1.3
