# %% [markdown]
# Parámetros
# | | Sector | Alpha | Beta | Loc (Mu) | Scale (Sigma) | KS Statistic | P-Value | Horizonte temporal |
# |:---:|:---|:---:|:---:|:---:|:---:|:---:|:---:|:---|
# | **0** | COME | 1.921988 | 0.999990 | 0.000520 | 0.010091 | 0.068913 | 0.914859 | 3 meses |
# | **1** | MOA | 1.623973 | 0.580927 | 0.001307 | 0.010535 | 0.047740 | 0.997955 | 3 meses |
# | **2** | MOI | 1.999994 | -0.172058 | 0.000450 | 0.012284 | 0.084171 | 0.748594 | 3 meses |
# | **3** | AGRO | 1.999998 | 0.297929 | 0.000234 | 0.013766 | 0.047142 | 0.998300 | 3 meses |
# | **4** | ENE | 2.000000 | -1.000000 | 0.002323 | 0.018403 | 0.063658 | 0.952397 | 3 meses |
# | **5** | FIN | 1.907617 | -0.999973 | -0.002929 | 0.017263 | 0.059350 | 0.973944 | 3 meses |
# | **6** | TOTAL | 2.000000 | -1.000000 | 0.001161 | 0.012511 | 0.101851 | 0.518578 | 3 meses |

# %%
#simu2mdo_ae
# Parámetros con colas más pesadas (Alpha reducido  en un 20% para aumentar Curtosis)
params_COME = {"alpha": 1.921988, "beta": 0.999990, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.99}
params_MOA  = {"alpha": 1.623973, "beta": 0.580927, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.99}
params_MOI  = {"alpha": 1.999994, "beta": -0.172058, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.99}
params_AGRO = {"alpha": 1.999998, "beta": 0.297929, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.99}
params_ENE  = {"alpha": 2.000000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.99}
params_FIN  = {"alpha": 1.907617, "beta": -0.999973, "mu": -0.002929, "sigma": 0.017263, "entropy": 0.99}

# %%
# simu3mdo+variab _be
#--- DEFINICIÓN DE PARÁMETROS INDEPENDIENTES ---
# Se duplicó el parámetro 'sigma' (variabilidad/escala) en todos los sectores.
# Este cambio incrementa la dispersión de los retornos, simulando un mercado con mayor volatilidad.

params_COME = {"alpha": 1.921988, "beta": 0.999990, "mu": 0.000520, "sigma": 0.020182, "entropy": 0.30} # Sigma: 0.010091 * 2
params_MOA  = {"alpha": 1.623973, "beta": 0.580927, "mu": 0.001307, "sigma": 0.021070, "entropy": 0.40} # Sigma: 0.010535 * 2
params_MOI  = {"alpha": 1.999994, "beta": -0.172058, "mu": 0.000450, "sigma": 0.024568, "entropy": 0.40} # Sigma: 0.012284 * 2
params_AGRO = {"alpha": 1.999998, "beta": 0.297929, "mu": 0.000234, "sigma": 0.027532, "entropy": 0.30} # Sigma: 0.013766 * 2
params_ENE  = {"alpha": 2.000000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.036806, "entropy": 0.30} # Sigma: 0.018403 * 2
params_FIN  = {"alpha": 1.907617, "beta": -0.999973, "mu": -0.002929, "sigma": 0.034526, "entropy": 0.40} # Sigma: 0.017263 * 2

# %%
#  simu4mdo+variab_ae
# --- Parámetros con Sigma Duplicado para aumentar variabilidad
# Se duplicó el parámetro 'sigma' (variabilidad/escala) en todos los sectores.
# Este cambio incrementa la dispersión de los retornos, simulando un mercado con mayor volatilidad.

params_COME = {"alpha": 1.921988, "beta": 0.999990, "mu": 0.000520, "sigma": 0.020182, "entropy": 0.99} # Sigma: 0.010091 * 2
params_MOA  = {"alpha": 1.623973, "beta": 0.580927, "mu": 0.001307, "sigma": 0.021070, "entropy": 0.99} # Sigma: 0.010535 * 2
params_MOI  = {"alpha": 1.999994, "beta": -0.172058, "mu": 0.000450, "sigma": 0.024568, "entropy": 0.99} # Sigma: 0.012284 * 2
params_AGRO = {"alpha": 1.999998, "beta": 0.297929, "mu": 0.000234, "sigma": 0.027532, "entropy": 0.99} # Sigma: 0.013766 * 2
params_ENE  = {"alpha": 2.000000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.036806, "entropy": 0.99} # Sigma: 0.018403 * 2
params_FIN  = {"alpha": 1.907617, "beta": -0.999973, "mu": -0.002929, "sigma": 0.034526, "entropy": 0.99} # Sigma: 0.017263 * 2

# %%
#simu5mdocp_be
# Parámetros con colas más pesadas (Alpha reducido en un 20% para aumentar Curtosis)
# Se redujo alpha para alejarlo de 2.0 (distribución normal) y generar colas más pesadas.
# A menor alpha, mayor es la probabilidad de eventos extremos (ineficiencia).
params_COME = {"alpha": 1.550000, "beta": 0.999990, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.30} # alpha bajó de 1.92 a 1.55

# Se redujo alpha de 1.62 a 1.40 para acentuar la pesadez de las colas.
params_MOA  = {"alpha": 1.400000, "beta": 0.580927, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.40} 

# Se redujo alpha de 1.99 a 1.60 para romper la simetría casi normal.
params_MOI  = {"alpha": 1.600000, "beta": -0.172058, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.40} 

# AGRO tenía un alpha de 1.99 (casi normal), se bajó a 1.50 para simular colas pesadas.
params_AGRO = {"alpha": 1.500000, "beta": 0.297929, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.30} 

# ENE era una normal perfecta (alpha=2.0), se bajó a 1.65 para introducir leptocurtosis.
params_ENE  = {"alpha": 1.650000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.30} 

# FIN se ajustó de 1.90 a 1.58 para incrementar la probabilidad de outliers.
params_FIN  = {"alpha": 1.580000, "beta": -0.999973, "mu": -0.002929, "sigma": 0.017263, "entropy": 0.40}

# %%
#simu6mdocp_ae
# Parámetros con colas más pesadas (Alpha reducido en un 20% para aumentar Curtosis)
# Se redujo alpha para alejarlo de 2.0 (distribución normal) y generar colas más pesadas.
# A menor alpha, mayor es la probabilidad de eventos extremos (ineficiencia).
params_COME = {"alpha": 1.550000, "beta": 0.999990, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.99} # alpha bajó de 1.92 a 1.55

# Se redujo alpha de 1.62 a 1.40 para acentuar la pesadez de las colas.
params_MOA  = {"alpha": 1.400000, "beta": 0.580927, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.99} 

# Se redujo alpha de 1.99 a 1.60 para romper la simetría casi normal.
params_MOI  = {"alpha": 1.600000, "beta": -0.172058, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.99} 

# AGRO tenía un alpha de 1.99 (casi normal), se bajó a 1.50 para simular colas pesadas.
params_AGRO = {"alpha": 1.500000, "beta": 0.297929, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.99} 

# ENE era una normal perfecta (alpha=2.0), se bajó a 1.65 para introducir leptocurtosis.
params_ENE  = {"alpha": 1.650000, "beta": -1.000000, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.99} 

# FIN se ajustó de 1.90 a 1.58 para incrementar la probabilidad de outliers.
params_FIN  = {"alpha": 1.580000, "beta": -0.999973, "mu": -0.002929, "sigma": 0.017263, "entropy": 0.99}

# %%
# simu7mdo_asim_be

# Parámetros con asimetría extrema (Skewness severa) valores de β hacia los extremos -1 y 1
#(-1 (Asimetría total hacia la izquierda (valores negativos extremos/caídas bruscas) representa caída del mercado y 1 (Asimetría total hacia la derechavalores positivos extremos).
# Los valores positivos indican sesgo hacia ganancias extremas y los negativos hacia pérdidas extremas.

params_COME = {"alpha": 1.921988, "beta": 0.990000, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.30} # Era 0.99 (positivo), se mantuvo positivo en 0.99
params_MOA  = {"alpha": 1.623973, "beta": 0.950000, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.40} # Era 0.58 (positivo), se subió a 0.95
params_MOI  = {"alpha": 1.999994, "beta": -0.960000, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.40} # Era -0.17 (negativo), se extremó a -0.96
params_AGRO = {"alpha": 1.999998, "beta": 0.950000, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.30} # Era 0.29 (positivo), se subió a 0.95
params_ENE  = {"alpha": 2.000000, "beta": -1.00, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.30} # Era -1.0 (negativo), se mantuvo

# %%
# simu8mdo_asim_ae

# Parámetros con asimetría extrema (Skewness severa) valores de β hacia los extremos -1 y 1
#(-1 (Asimetría total hacia la izquierda (valores negativos extremos/caídas bruscas) representa caída del mercado y 1 (Asimetría total hacia la derechavalores positivos extremos).
# Los valores positivos indican sesgo hacia ganancias extremas y los negativos hacia pérdidas extremas.

params_COME = {"alpha": 1.921988, "beta": 0.990000, "mu": 0.000520, "sigma": 0.010091, "entropy": 0.99} # Era 0.99 (positivo), se mantuvo positivo en 0.99
params_MOA  = {"alpha": 1.623973, "beta": 0.950000, "mu": 0.001307, "sigma": 0.010535, "entropy": 0.99} # Era 0.58 (positivo), se subió a 0.95
params_MOI  = {"alpha": 1.999994, "beta": -0.960000, "mu": 0.000450, "sigma": 0.012284, "entropy": 0.99} # Era -0.17 (negativo), se extremó a -0.96
params_AGRO = {"alpha": 1.999998, "beta": 0.950000, "mu": 0.000234, "sigma": 0.013766, "entropy": 0.99} # Era 0.29 (positivo), se subió a 0.95
params_ENE  = {"alpha": 2.000000, "beta": -1.00, "mu": 0.002323, "sigma": 0.018403, "entropy": 0.99} # Era -1.0 (negativo), se mantuvo
